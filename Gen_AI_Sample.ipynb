# %%
import os
os.environ['GEMINI_API_KEY'] = 'AIzaSyB5j2yS8rhObi8TsoX_dJxM5BQSjqeycbI'

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai
genai.configure(api_key=os.environ['GEMINI_API_KEY'])

# %%
model = genai.GenerativeModel('gemini-2.5-flash-preview-04-17')

# %%
response = model.generate_content('create a table to explain about ai, generative ai and agentic ai')
print(response.text)
# Out:
# Okay, here is a table comparing AI, Generative AI, and Agentic AI, highlighting their key characteristics and differences.
#
# **Comparing AI, Generative AI, and Agentic AI**
#
# | Feature             | AI (Artificial Intelligence)                    | Generative AI                                       | Agentic AI                                                                 |
# | :------------------ | :---------------------------------------------- | :-------------------------------------------------- | :------------------------------------------------------------------------- |
# | **What it is**      | The broad field of creating machines capable of performing tasks typically requiring human intelligence. | A specific type/subset of AI focused on creating *new* content or data. | An emerging paradigm within AI where systems act as autonomous or semi-autonomous *agents* to achieve goals. |
# ...

# %%
import PIL.Image

img = PIL.Image.open('/content/Screenshot 2024-05-01 104937.png')

img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1616x540>

# %%
model = genai.GenerativeModel('gemini-2.5-flash-preview-04-17')

# %%
response = model.generate_content(img)
print(response)
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
# ...

# %%
response = model.generate_content(img)
print(response.text)
# Out:
# The image is a wedding photo album spread. The left side features a textured beige background with watercolor-style purple and green floral illustrations. It contains two smaller inset photographs: one of the bride looking away and to the right, wearing a red and gold outfit with a headscarf and elaborate jewelry, and another of the groom smiling while holding sunglasses, also wearing a red shirt. Text at the top reads "Ashad + Abida Aqueeb", and text at the bottom says "There is only one happiness in life, to love and to be loved." The left and right sides are visually separated by a rough, torn paper edge effect. The right side features a large photograph of the bride and groom together. The bride is in the foreground, wearing a similar red and gold outfit and significant gold jewelry. The groom is standing slightly behind her to the right, wearing a red collared shirt. They are both smiling and looking towards the left. The background of the right side photo is a light blue/grey w
# ...
